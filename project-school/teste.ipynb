# %%
import pandas as pd

dados = pd.read_csv("dados.csv")
dados
# Out:
#   Salas:    Séries:
# 0   Sala_1    1°ano
# 1   Sala_2    2°ano
# 2   Sala_3    3°ano
# 3   Sala_4    4°ano
# 4   Sala_5    5°ano
# 5   Sala_6    6°ano
# 6   Sala_7    7°ano
# 7   Sala_8    8°ano
