# %%
import pandas as pd

pergunta = str(input("Qual sala você é? ")).strip()
dados = pd.read_csv("dados.csv", header=0, names=('salas', 'series'))
print(dados.columns.tolist())
resultado = dados[dados["series"] == pergunta]

if not resultado.empty:
    sala = resultado.iloc[0['salas']]
    print("Entendi, sua série é {}, você está na sala {}".format(resultado,pergunta))
else:
    print("Série não encontrada, tente novamente")
# Out:
# <>:9: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:9: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# ['salas', 'series']
# C:\Users\danie\AppData\Local\Temp\ipykernel_13532\3504583675.py:9: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   sala = resultado.iloc[0['salas']]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 9
#       5 print(dados.columns.tolist())
#       6 resultado = dados[dados["series"] == pergunta]
#       7
#       8 if not resultado.empty:
# ----> 9     sala = resultado.iloc[0['salas']]
#      10     print("Entendi, sua série é {}, você está na sala {}".format(resultado,pergunta))
#      11 else:
#      12     print("Série não encontrada, tente novamente")
#
# TypeError: 'int' object is not subscriptable
